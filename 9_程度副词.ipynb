# %%
# -*- coding:utf-8 -*-

with open(r'./HowNet_sentiment/程度级别词语（中文）.txt') as f:
    chinese_adv_degree = f.read()

# %%
chinese_adv_degree.split('\n')
# Out:
# ['中文程度级别词语\t\t219',
#  '',
#  '1. “极其|extreme / 最|most”\t69',
#  '百分之百',
#  '倍加',
#  '备至',
#  '不得了',
#  '不堪',
#  '不可开交',
#  '不亦乐乎',
#  '不折不扣',
#  '彻头彻尾',
#  '充分',
#  '到头',
#  '地地道道',
#  '非常',
#  '极',
#  '极度',
#  '极端',
#  '极其',
#  '极为',
#  '截然',
#  '尽',
#  '惊人地',
#  '绝',
#  '绝顶',
#  '绝对',
#  '绝对化',
#  '刻骨',
#  '酷',
#  '满',
#  '满贯',
#  '满心',
#  '莫大',
#  '奇',
#  '入骨',
#  '甚为',
#  '十二分',
#  '十分',
#  '十足',
#  '死',
#  '滔天',
#  '痛',
#  '透',
#  '完全',
#  '完完全全',
#  '万',
#  '万般',
#  '万分',
#  '万万',
#  '无比',
#  '无度',
#  '无可估量',
#  '无以复加',
#  '无以伦比',
#  '要命',
#  '要死',
#  '已极',
#  '已甚',
#  '异常',
#  '逾常',
#  '贼',
#  '之极',
#  '之至',
#  '至极',
#  '卓绝',
#  '最为',
#  '佼佼',
#  '郅',
#  '綦',
#  '齁',
#  '最',
#  '',
#  '2. “很|very”\t42',
#  '不过',
#  '不少',
#  '不胜',
#  '惨',
#  '沉',
#  '沉沉',
#  '出奇',
#  '大为',
#  '多',
#  '多多',
#  '多加',
#  '多么',
#  '分外',
#  '格外',
#  '够瞧的',
#  '够戗',
#  '好',
#  '好不',
#  '何等',
#  '很',
#  '很是',
#  '坏',
#  '可',
#  '老',
#  '老大',
#  '良',
#  '颇',
#  '颇为',
#  '甚',
#  '实在',
#  '太',
#  '太甚',
# ...

# %%
level6 = ['不为过',
 '超',
 '超额',
 '超外差',
 '超微结构',
 '超物质',
 '出头',
 '多',
 '浮',
 '过',
 '过度',
 '过分',
 '过火',
 '过劲',
 '过了头',
 '过猛',
 '过热',
 '过甚',
 '过头',
 '过于',
 '过逾',
 '何止',
 '何啻',
 '开外',
 '苦',
 '老',
 '偏',
 '强',
 '溢',
 '忒']

# %%
level5 = ['百分之百',
 '倍加',
 '备至',
 '不得了',
 '不堪',
 '不可开交',
 '不亦乐乎',
 '不折不扣',
 '彻头彻尾',
 '充分',
 '到头',
 '地地道道',
 '非常',
 '极',
 '极度',
 '极端',
 '极其',
 '极为',
 '截然',
 '尽',
 '惊人地',
 '绝',
 '绝顶',
 '绝对',
 '绝对化',
 '刻骨',
 '酷',
 '满',
 '满贯',
 '满心',
 '莫大',
 '奇',
 '入骨',
 '甚为',
 '十二分',
 '十分',
 '十足',
 '死',
 '滔天',
 '痛',
 '透',
 '完全',
 '完完全全',
 '万',
 '万般',
 '万分',
 '万万',
 '无比',
 '无度',
 '无可估量',
 '无以复加',
 '无以伦比',
 '要命',
 '要死',
 '已极',
 '已甚',
 '异常',
 '逾常',
 '贼',
 '之极',
 '之至',
 '至极',
 '卓绝',
 '最为',
 '佼佼',
 '郅',
 '綦',
 '齁',
 '最']

# %%
level4 = ['不过',
 '不少',
 '不胜',
 '惨',
 '沉',
 '沉沉',
 '出奇',
 '大为',
 '多',
 '多多',
 '多加',
 '多么',
 '分外',
 '格外',
 '够瞧的',
 '够戗',
 '好',
 '好不',
 '何等',
 '很',
 '很是',
 '坏',
 '可',
 '老',
 '老大',
 '良',
 '颇',
 '颇为',
 '甚',
 '实在',
 '太',
 '太甚',
 '特',
 '特别',
 '尤',
 '尤其',
 '尤为',
 '尤以',
 '远',
 '着实',
 '曷',
 '碜']

# %%
level3=['大不了',
 '多',
 '更',
 '更加',
 '更进一步',
 '更为',
 '还',
 '还要',
 '较',
 '较比',
 '较为',
 '进一步',
 '那般',
 '那么',
 '那样',
 '强',
 '如斯',
 '益',
 '益发',
 '尤甚',
 '逾',
 '愈',
 '愈 ... 愈',
 '愈发',
 '愈加',
 '愈来愈',
 '愈益',
 '远远',
 '越 ... 越',
 '越发',
 '越加',
 '越来越',
 '越是',
 '这般',
 '这样',
 '足',
 '足足']

# %%
level2=['点点滴滴',
 '多多少少',
 '怪',
 '好生',
 '还',
 '或多或少',
 '略',
 '略加',
 '略略',
 '略微',
 '略为',
 '蛮',
 '稍',
 '稍稍',
 '稍微',
 '稍为',
 '稍许',
 '挺',
 '未免',
 '相当',
 '些',
 '些微',
 '些小',
 '一点',
 '一点儿',
 '一些',
 '有点',
 '有点儿',
 '有些']

# %%
level1=['半点',
 '不大',
 '不丁点儿',
 '不甚',
 '不怎么',
 '聊',
 '没怎么',
 '轻度',
 '弱',
 '丝毫',
 '微',
 '相对']

# %%
level_over=['不为过',
 '超',
 '超额',
 '超外差',
 '超微结构',
 '超物质',
 '出头',
 '多',
 '浮',
 '过',
 '过度',
 '过分',
 '过火',
 '过劲',
 '过了头',
 '过猛',
 '过热',
 '过甚',
 '过头',
 '过于',
 '过逾',
 '何止',
 '何啻',
 '开外',
 '苦',
 '老',
 '偏',
 '强',
 '溢',
 '忒']

# %%
valuelevel1 = len(level1)*['1']
dictionary_level1 = dict(zip(level1, valuelevel1))
dictionary_level1
# Out:
# {'半点': '1',
#  '不大': '1',
#  '不丁点儿': '1',
#  '不甚': '1',
#  '不怎么': '1',
#  '聊': '1',
#  '没怎么': '1',
#  '轻度': '1',
#  '弱': '1',
#  '丝毫': '1',
#  '微': '1',
#  '相对': '1'}

# %%
dictionary_level2 = dict(zip(level2, len(level2)*['2']))
dictionary_level2
# Out:
# {'点点滴滴': '2',
#  '多多少少': '2',
#  '怪': '2',
#  '好生': '2',
#  '还': '2',
#  '或多或少': '2',
#  '略': '2',
#  '略加': '2',
#  '略略': '2',
#  '略微': '2',
#  '略为': '2',
#  '蛮': '2',
#  '稍': '2',
#  '稍稍': '2',
#  '稍微': '2',
#  '稍为': '2',
#  '稍许': '2',
#  '挺': '2',
#  '未免': '2',
#  '相当': '2',
#  '些': '2',
#  '些微': '2',
#  '些小': '2',
#  '一点': '2',
#  '一点儿': '2',
#  '一些': '2',
#  '有点': '2',
#  '有点儿': '2',
#  '有些': '2'}

# %%
dictionary_level3 = dict(zip(level3, len(level3)*['3']))
dictionary_level3
# Out:
# {'大不了': '3',
#  '多': '3',
#  '更': '3',
#  '更加': '3',
#  '更进一步': '3',
#  '更为': '3',
#  '还': '3',
#  '还要': '3',
#  '较': '3',
#  '较比': '3',
#  '较为': '3',
#  '进一步': '3',
#  '那般': '3',
#  '那么': '3',
#  '那样': '3',
#  '强': '3',
#  '如斯': '3',
#  '益': '3',
#  '益发': '3',
#  '尤甚': '3',
#  '逾': '3',
#  '愈': '3',
#  '愈 ... 愈': '3',
#  '愈发': '3',
#  '愈加': '3',
#  '愈来愈': '3',
#  '愈益': '3',
#  '远远': '3',
#  '越 ... 越': '3',
#  '越发': '3',
#  '越加': '3',
#  '越来越': '3',
#  '越是': '3',
#  '这般': '3',
#  '这样': '3',
#  '足': '3',
#  '足足': '3'}

# %%
dictionary_level4 = dict(zip(level4, len(level4)*['4']))
dictionary_level4
# Out:
# {'不过': '4',
#  '不少': '4',
#  '不胜': '4',
#  '惨': '4',
#  '沉': '4',
#  '沉沉': '4',
#  '出奇': '4',
#  '大为': '4',
#  '多': '4',
#  '多多': '4',
#  '多加': '4',
#  '多么': '4',
#  '分外': '4',
#  '格外': '4',
#  '够瞧的': '4',
#  '够戗': '4',
#  '好': '4',
#  '好不': '4',
#  '何等': '4',
#  '很': '4',
#  '很是': '4',
#  '坏': '4',
#  '可': '4',
#  '老': '4',
#  '老大': '4',
#  '良': '4',
#  '颇': '4',
#  '颇为': '4',
#  '甚': '4',
#  '实在': '4',
#  '太': '4',
#  '太甚': '4',
#  '特': '4',
#  '特别': '4',
#  '尤': '4',
#  '尤其': '4',
#  '尤为': '4',
#  '尤以': '4',
#  '远': '4',
#  '着实': '4',
#  '曷': '4',
#  '碜': '4'}

# %%
dictionary_level5 = dict(zip(level5, len(level5)*['5']))
dictionary_level5
# Out:
# {'百分之百': '5',
#  '倍加': '5',
#  '备至': '5',
#  '不得了': '5',
#  '不堪': '5',
#  '不可开交': '5',
#  '不亦乐乎': '5',
#  '不折不扣': '5',
#  '彻头彻尾': '5',
#  '充分': '5',
#  '到头': '5',
#  '地地道道': '5',
#  '非常': '5',
#  '极': '5',
#  '极度': '5',
#  '极端': '5',
#  '极其': '5',
#  '极为': '5',
#  '截然': '5',
#  '尽': '5',
#  '惊人地': '5',
#  '绝': '5',
#  '绝顶': '5',
#  '绝对': '5',
#  '绝对化': '5',
#  '刻骨': '5',
#  '酷': '5',
#  '满': '5',
#  '满贯': '5',
#  '满心': '5',
#  '莫大': '5',
#  '奇': '5',
#  '入骨': '5',
#  '甚为': '5',
#  '十二分': '5',
#  '十分': '5',
#  '十足': '5',
#  '死': '5',
#  '滔天': '5',
#  '痛': '5',
#  '透': '5',
#  '完全': '5',
#  '完完全全': '5',
#  '万': '5',
#  '万般': '5',
#  '万分': '5',
#  '万万': '5',
#  '无比': '5',
#  '无度': '5',
#  '无可估量': '5',
#  '无以复加': '5',
#  '无以伦比': '5',
#  '要命': '5',
#  '要死': '5',
#  '已极': '5',
#  '已甚': '5',
#  '异常': '5',
#  '逾常': '5',
#  '贼': '5',
#  '之极': '5',
#  '之至': '5',
#  '至极': '5',
#  '卓绝': '5',
#  '最为': '5',
#  '佼佼': '5',
#  '郅': '5',
#  '綦': '5',
#  '齁': '5',
#  '最': '5'}

# %%
valuelevel6 = len(level6)*['6']
dictionary_level6 = dict(zip(level6, valuelevel6))
dictionary_level6
# Out:
# {'不为过': '6',
#  '超': '6',
#  '超额': '6',
#  '超外差': '6',
#  '超微结构': '6',
#  '超物质': '6',
#  '出头': '6',
#  '多': '6',
#  '浮': '6',
#  '过': '6',
#  '过度': '6',
#  '过分': '6',
#  '过火': '6',
#  '过劲': '6',
#  '过了头': '6',
#  '过猛': '6',
#  '过热': '6',
#  '过甚': '6',
#  '过头': '6',
#  '过于': '6',
#  '过逾': '6',
#  '何止': '6',
#  '何啻': '6',
#  '开外': '6',
#  '苦': '6',
#  '老': '6',
#  '偏': '6',
#  '强': '6',
#  '溢': '6',
#  '忒': '6'}

# %%
dict_level = {}
dict_level.update(dictionary_level1)

# %%
dict_level.update(dictionary_level2)

# %%
dict_level.update(dictionary_level3)

# %%
dict_level.update(dictionary_level4)

# %%
dict_level.update(dictionary_level5)

# %%
dict_level.update(dictionary_level6)

# %%
dict_level
# Out:
# {'半点': '1',
#  '不大': '1',
#  '不丁点儿': '1',
#  '不甚': '1',
#  '不怎么': '1',
#  '聊': '1',
#  '没怎么': '1',
#  '轻度': '1',
#  '弱': '1',
#  '丝毫': '1',
#  '微': '1',
#  '相对': '1',
#  '点点滴滴': '2',
#  '多多少少': '2',
#  '怪': '2',
#  '好生': '2',
#  '还': '3',
#  '或多或少': '2',
#  '略': '2',
#  '略加': '2',
#  '略略': '2',
#  '略微': '2',
#  '略为': '2',
#  '蛮': '2',
#  '稍': '2',
#  '稍稍': '2',
#  '稍微': '2',
#  '稍为': '2',
#  '稍许': '2',
#  '挺': '2',
#  '未免': '2',
#  '相当': '2',
#  '些': '2',
#  '些微': '2',
#  '些小': '2',
#  '一点': '2',
#  '一点儿': '2',
#  '一些': '2',
#  '有点': '2',
#  '有点儿': '2',
#  '有些': '2',
#  '大不了': '3',
#  '多': '6',
#  '更': '3',
#  '更加': '3',
#  '更进一步': '3',
#  '更为': '3',
#  '还要': '3',
#  '较': '3',
#  '较比': '3',
#  '较为': '3',
#  '进一步': '3',
#  '那般': '3',
#  '那么': '3',
#  '那样': '3',
#  '强': '6',
#  '如斯': '3',
#  '益': '3',
#  '益发': '3',
#  '尤甚': '3',
#  '逾': '3',
#  '愈': '3',
#  '愈 ... 愈': '3',
#  '愈发': '3',
#  '愈加': '3',
#  '愈来愈': '3',
#  '愈益': '3',
#  '远远': '3',
#  '越 ... 越': '3',
#  '越发': '3',
# ...

# %%
import pickle

save_dict_level = open('dict_level.pkl','wb')
pickle.dump(dict_level, save_dict_level)
save_dict_level.close()

# %%
read_dict_level = open('dict_level.pkl','rb')
dict_level = pickle.load(read_dict_level)
read_dict_level.close()

# %%
dict_level
# Out:
# {'半点': '1',
#  '不大': '1',
#  '不丁点儿': '1',
#  '不甚': '1',
#  '不怎么': '1',
#  '聊': '1',
#  '没怎么': '1',
#  '轻度': '1',
#  '弱': '1',
#  '丝毫': '1',
#  '微': '1',
#  '相对': '1',
#  '点点滴滴': '2',
#  '多多少少': '2',
#  '怪': '2',
#  '好生': '2',
#  '还': '3',
#  '或多或少': '2',
#  '略': '2',
#  '略加': '2',
#  '略略': '2',
#  '略微': '2',
#  '略为': '2',
#  '蛮': '2',
#  '稍': '2',
#  '稍稍': '2',
#  '稍微': '2',
#  '稍为': '2',
#  '稍许': '2',
#  '挺': '2',
#  '未免': '2',
#  '相当': '2',
#  '些': '2',
#  '些微': '2',
#  '些小': '2',
#  '一点': '2',
#  '一点儿': '2',
#  '一些': '2',
#  '有点': '2',
#  '有点儿': '2',
#  '有些': '2',
#  '大不了': '3',
#  '多': '6',
#  '更': '3',
#  '更加': '3',
#  '更进一步': '3',
#  '更为': '3',
#  '还要': '3',
#  '较': '3',
#  '较比': '3',
#  '较为': '3',
#  '进一步': '3',
#  '那般': '3',
#  '那么': '3',
#  '那样': '3',
#  '强': '6',
#  '如斯': '3',
#  '益': '3',
#  '益发': '3',
#  '尤甚': '3',
#  '逾': '3',
#  '愈': '3',
#  '愈 ... 愈': '3',
#  '愈发': '3',
#  '愈加': '3',
#  '愈来愈': '3',
#  '愈益': '3',
#  '远远': '3',
#  '越 ... 越': '3',
#  '越发': '3',
# ...

# %%
len(dict_level)
# Out:
# 214
